# %%
from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression data.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]
# print(dftd_cells_csv[0])

locations = devil_data["population"]
dftd_cells = {}
cell_reduction = {}

for i in range(len(dftd_cells_csv)):
    if locations[i] not in dftd_cells:
        dftd_cells[locations[i]] = [dftd_cells_csv[i]]
        cell_reduction[locations[i]] = [cell_reduction_csv[i]]
    else:
        dftd_cells[locations[i]].append(dftd_cells_csv[i])
        cell_reduction[locations[i]].append(cell_reduction_csv[i])

locations_set = list(set(locations))
print(type(locations_set))
print(locations_set[0])
print(len(locations_set))
colours = ["#FF0000", "#00FF00", "#0000FF", "#FFFF00", "#FF00FF", "#00FFFF", "#800000", "#808000",
           "#008000", "#800080", "#008080", "#000080", "#FFA500", "#A52A2A", "#5F9EA0", "#7FFF00",
           "#D2691E", "#6495ED", "#DC143C", "#006400", "#8B008B", "#556B2F", "#FF8C00", "#9932CC",
           "#8B0000", "#E9967A", "#9400D3", "#FF1493", "#00BFFF", "#696969", "#1E90FF", "#FFD700"]
for i in range(len(locations_set)):
    x = np.array(dftd_cells[locations_set[i]])
    y = np.array(cell_reduction[locations_set[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    # y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label='Data')
    # plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')

plt.xlabel('DFTD Cells')
plt.ylabel('Cell Reduction')
plt.title('Linear Regression Example')
plt.legend()
plt.show()

# Print model parameters
# print("Coefficient (Slope):", model.coef_[0])
# print("Intercept:", model.intercept_)
# calculate and print R^2
# print("R^2:", r2_score(y, y_pred))
# Out:
# <class 'list'>
# Fentonbury
# 39
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 39
#      37     model.fit(x[:, np.newaxis], y)
#      38     # y_pred = model.predict(x[:, np.newaxis])
# ---> 39     plt.scatter(x, y, color=colours[i], label='Data')
#      40     # plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')
#      42 plt.xlabel('DFTD Cells')
#
# IndexError: list index out of range

# %%
# TESTING FEMALE AND MALE

from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression data.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]
sex_csv = devil_data["sex"]

locations = devil_data["population"]
dftd_cells = {"female": [], "male": [], "unknown": []}
cell_reduction = {"female": [], "male": [], "unknown": []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[sex_csv[i]].append(dftd_cells_csv[i])
    cell_reduction[sex_csv[i]].append(cell_reduction_csv[i])

sex = list(set(sex_csv))
colours = ["green", "red", "purple"]
for i in range(len(sex)):
    x = np.array(dftd_cells[sex[i]])
    y = np.array(cell_reduction[sex[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=sex[i])
    # plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')
    # #Print model parameters
    # print("Coefficient (Slope):", model.coef_[0])
    # print("Intercept:", model.intercept_)
    # #calculate and print R^2
    # print("R^2:", r2_score(y, y_pred))

plt.xlabel('DFTD Cells')
plt.ylabel('Cell Reduction')
plt.title('Linear Regression of DFTD')
plt.legend()
plt.show()

# %%
# TESTING CHEM DRUG (YES/NO) VS CELL REDUCTION
# NOTE: CELL REDUCTION IS FINAL CELL COUNT
from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression UPDATED 2025.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]
chem_drug_c_csv = devil_data["chem_drug_c"]

locations = devil_data["population"]
dftd_cells = {"yes": [], "no": []}
cell_reduction = {"yes": [], "no": []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[chem_drug_c_csv[i]].append(dftd_cells_csv[i])
    cell_reduction[chem_drug_c_csv[i]].append(cell_reduction_csv[i])

chem_drug_c = list(set(chem_drug_c_csv))
colours = ["green","red"]
for i in range(len(chem_drug_c)):
    x = np.array(dftd_cells[chem_drug_c[i]])
    y = np.array(cell_reduction[chem_drug_c[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=chem_drug_c[i])
    plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')
    # Print model parameters
    print("Coefficient (Slope):", model.coef_[0])
    print("Intercept:", model.intercept_)
    # calculate and print R^2
    print("R^2:", r2_score(y, y_pred))

plt.xlabel('DFTD Cells')
plt.ylabel('Cell Reduction')
plt.title('Yes vs No Chem Drug C')
plt.legend()
plt.show()

print(dftd_cells)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cell_reduction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 12
# ...

# %%
# TESTING CHEM DRUG (YES/NO) VS CELL REDUCTION
# NOTE: CELL REDUCTION IS FINAL CELL COUNT
from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression data.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]
chem_drug_c_csv = devil_data["chem_drug_c"]

locations = devil_data["population"]
dftd_cells = {"yes": [], "no": []}
cell_reduction = {"yes": [], "no": []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[chem_drug_c_csv[i]].append(dftd_cells_csv[i])
    cell_reduction[chem_drug_c_csv[i]].append(cell_reduction_csv[i])

chem_drug_c = list(set(chem_drug_c_csv))
colours = ["green", "red"]
for i in range(len(chem_drug_c)):
    x = np.array(dftd_cells[chem_drug_c[i]])
    y = np.array(cell_reduction[chem_drug_c[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=chem_drug_c[i])
    plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')
    # Print model parameters
    print("Coefficient (Slope):", model.coef_[0])
    print("Intercept:", model.intercept_)
    # calculate and print R^2
    print("R^2:", r2_score(y, y_pred))

plt.xlabel('DFTD Cells')
plt.ylabel('Growth Factor ((CR - DFTD)/DFTD)')
plt.title('Yes vs No Chem Drug C')
plt.legend()
plt.show()

print(dftd_cells)

# %%
# TESTING POOL

from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression data.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]
pool_csv = devil_data["pool"]
pools = list(set(pool_csv))

dftd_cells = {pools[0]: [], pools[1]: [], pools[2]: [], pools[3]: []}
cell_reduction = {pools[0]: [], pools[1]: [], pools[2]: [], pools[3]: []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[pool_csv[i]].append(dftd_cells_csv[i])
    cell_reduction[pool_csv[i]].append(cell_reduction_csv[i])

colours = ["red", "yellow", "green", "purple"]
for i in range(len(pools)):
    x = np.array(dftd_cells[pools[i]])
    y = np.array(cell_reduction[pools[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    # y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=pools[i])
    # plt.plot(x, y_pred, color=colours[i], linewidth=3, label='Linear fit')
    #Print model parameters
    # print("Coefficient (Slope):", model.coef_[0])
    # print("Intercept:", model.intercept_)
    # #calculate and print R^2
    # print("R^2:", r2_score(y, y_pred))

plt.xlabel('DFTD Cells')
plt.ylabel('Cell Reduction')
plt.title('Model for DFTD vs Cell Reduction, Scatter Plot Colours by Pool Number')
plt.legend()
plt.show()

# %%
from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression data.csv')
dftd_cells_csv = devil_data["dftd_cells"]
cell_reduction_csv = devil_data["cell_reduction"]

year_csv = devil_data["year"]
dftd_cells = {}
cell_reduction = {}

for i in range(len(dftd_cells_csv)):
    if year_csv[i] not in dftd_cells:
        dftd_cells[year_csv[i]] = [dftd_cells_csv[i]]
        cell_reduction[year_csv[i]] = [cell_reduction_csv[i]]
    else:
        dftd_cells[year_csv[i]].append(dftd_cells_csv[i])
        cell_reduction[year_csv[i]].append(cell_reduction_csv[i])

years = list(set(year_csv))
print(len(years))
colours = ["#E6194B", "#3CB44B", "#FFE119", "#4363D8", "#F58231", "#911EB4", "#42D4F4", "#F032E6", "#BFEF45", "#FABEBE",
           "#469990", "#DCBEFF"]
for i in range(len(years)):
    x = np.array(dftd_cells[years[i]])
    y = np.array(cell_reduction[years[i]])
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    # y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=years[i])
    # plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')

plt.xlabel('DFTD Cells')
plt.ylabel('Cell Reduction')
plt.title('Model for DFTD vs Cell Reduction, Scatter Plot Colours by Year')
plt.legend()
plt.show()

# Print model parameters
# print("Coefficient (Slope):", model.coef_[0])
# print("Intercept:", model.intercept_)
# calculate and print R^2
# print("R^2:", r2_score(y, y_pred))
# Out:
# 12

# %%
# UPDATED DATA AAAHHSDF;LKASJDFJDAS;FKJASD;LKFJASDL;KFJ

from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression UPDATED 2025.csv')
dftd_cells_csv = devil_data["dftd_cells"]
final_cell_count_csv = devil_data["final_cell_count"]
chem_drug_c_csv = devil_data["chem_drug_c"]

dftd_cells = {"yes": [], "no": []}
final_cell_count = {"yes": [], "no": []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[chem_drug_c_csv[i]].append(dftd_cells_csv[i])
    final_cell_count[chem_drug_c_csv[i]].append(final_cell_count_csv[i])

chem_drug_c = list(set(chem_drug_c_csv))
colours = ["green","red"]
for i in range(len(chem_drug_c)):
    x = np.array(dftd_cells[chem_drug_c[i]])
    y = np.array(final_cell_count[chem_drug_c[i]])
    
    print(x)
    print(y)
    
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=chem_drug_c[i])
    plt.plot(x, y_pred, color='blue', linewidth=3, label='Linear fit')
    # Print model parameters
    print("Coefficient (Slope):", model.coef_[0])
    print("Intercept:", model.intercept_)
    # calculate and print R^2
    print("R^2:", r2_score(y, y_pred))

plt.xlabel('DFTD Cells')
plt.ylabel('Final Cell Count')
plt.title('Yes vs No Chem Drug C')
plt.legend()
plt.show()
# Out:
# [ 151  499  529  820  838 1684 2518 2721 2856 2983 4241 4790 4878 5702
#  5884 6659 6695 6878 7045 7303 7362 7664 7703 8133 8758 9230 9652  324
#  1002 2955 4403 8041 8574  152  155  359  396  529  703  824  884 1267
#  2531 3216 3435 4082 4371 4662 4686 5241 6082 6395 6606 7242 7623 7802
#  9336 9773  508  658 2071 2173 2935 3481 3717 4650 4778 5773 5945 6542
#  7023 7637 7721 8090 8643 9345   28  112  121  373  404  562  582  820
#   961 3195 5283 5950 6119 8710  224  831 2847 5588 6659 9529  202  532
#   628  922 1363 1684 2599 3000 3124 3210 3310 3978 4036 4311 5159 5984
#  6437 6606 7026 7422 7931 8344 8762 9471   24   25  219  297  404 1008
#  1609 1823 2359 2476 2529 2644 2760 5228 5622 5942 6358 6902 7216 7257
#  7498 7542 7980 8169 8829 8979 9490 9943 9975  669  902 1527 1740 2096
#  2447 2784 2858 2923 3030 3070 3478 3612 4432 4465 4523 4684 4769 5785
#  5873 5904 6339 6456 7086 7537 7853 8468 8810 8995 9987  939 1795 2054
# ...

# %%
# PLOT UPDATED DATA SEPARATELY FOR YES VS NO

# UPDATED DATA AAAHHSDF;LKASJDFJDAS;FKJASD;LKFJASDL;KFJ

from scipy.stats import f_oneway
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression  #THIS IS OUR REGRESSION PACKAGE
from sklearn.metrics import mean_squared_error, r2_score

devil_data = pd.read_csv('devil regression UPDATED 2025.csv')
dftd_cells_csv = devil_data["dftd_cells"]
final_cell_count_csv = devil_data["final_cell_count"]
chem_drug_c_csv = devil_data["chem_drug_c"]

dftd_cells = {"yes": [], "no": []}
final_cell_count = {"yes": [], "no": []}

for i in range(len(dftd_cells_csv)):
    dftd_cells[chem_drug_c_csv[i]].append(dftd_cells_csv[i])
    final_cell_count[chem_drug_c_csv[i]].append(final_cell_count_csv[i])

chem_drug_c = list(set(chem_drug_c_csv))
colours = ["red","green"]
for i in range(len(chem_drug_c)):
    x = np.array(dftd_cells[chem_drug_c[i]])
    y = np.array(final_cell_count[chem_drug_c[i]])
    
    # print(x)
    # print(y)
    
    model = LinearRegression()
    model.fit(x[:, np.newaxis], y)
    y_pred = model.predict(x[:, np.newaxis])
    plt.scatter(x, y, color=colours[i], label=chem_drug_c[i])
    plt.plot(x, y_pred, color='blue', linewidth=3, label='Line of Best Fit')
    plt.xlabel('DFTD Initial Cell Count')
    plt.ylabel('DFTD Final Cell Count')
    # if i ==0: 
    #     plt.title('DFTD Cell Count Before and After Without Vincristine')
    # elif i == 1:
    #     plt.title('DFTD Cell Count Before and After With Vincristine')
    plt.show()
    # Print model parameters
    print("Coefficient (Slope):", model.coef_[0])
    print("Intercept:", model.intercept_)
    # calculate and print R^2
    print("R^2:", r2_score(y, y_pred))



# fig1 = plt.figure()
# fig2 = plt.figure()
# 
# ax1 = fig1.add_subplot(111)
# ax2 = fig2.add_subplot(111)
# 
# ax1.plot(np.array(dftd_cells[chem_drug_c[0]]),np.array(final_cell_count[chem_drug_c[0]]))
# ax2.plot(np.array(dftd_cells[chem_drug_c[1]]),np.array(final_cell_count[chem_drug_c[1]]))


# plt.xlabel('DFTD Cells')
# plt.ylabel('Final Cell Count')
# plt.title('Yes vs No Chem Drug C')
# plt.legend()
# plt.show()
# Out:
# Coefficient (Slope): -8.105178795810597
# Intercept: 569453.2526486437
# R^2: 0.005601462381785605
# Coefficient (Slope): 0.9637843277663948
# Intercept: 261.3881022161095
# R^2: 0.9804921627322756
